# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans
import numpy as np
import pandas as pd
from time import time
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn import metrics

# %%
# Loading pre-processed data / Creating training and test data sets

# %%
training_data = pd.read_csv('cleaned_training_data.csv') # load cleaned data

# %%
training_data
# Out:
#                                                   review sentiment  \
# 0         one reviewers mentioned watching oz episode...  positive
# 1         wonderful little production filming techniq...  positive
# 2         thought wonderful way spend time hot summer...  positive
# 3         basically theres family little boy jake thi...  negative
# 4         petter matteis love time money visually stu...  positive
# ...                                                  ...       ...
# 39995     marvelously funny comedy great cast john ri...  positive
# 39996     plot central characters moving cameras clos...  positive
# 39997     show awesome love actors great story lines ...  positive
# 39998     fact movie entitled successful movie switze...  negative
# 39999     confess severely disappointedthis version w...  negative
#
#        Cont_Spoiler  Cont_End  \
# 0                 0     False
# 1                 0     False
# 2                 0     False
# 3                 0     False
# ...

# %%
test_csv = training_data.tail(10000)
train_csv = training_data.head(40000)

train_X = train_csv['lemmatization']    
train_y = train_csv["sentiment"]   
test_X = test_csv['lemmatization']
test_y = test_csv['sentiment']

# %%
# loading CountVectorizer
tf_vectorizer = TfidfVectorizer(stop_words='english') # create Object of class TfidfVectorizer


X_train_tf = tf_vectorizer.fit_transform(train_X) # run method fit_transform on training set

  
print("n_samples: %d, n_features: %d" % X_train_tf.shape)
# Out:
# n_samples: 40000, n_features: 174922

# %%
for index, value in train_y.items():

    print(f"Index : {index}, Value : {value}")
# Out:
# Index : 0, Value : positive
# Index : 1, Value : positive
# Index : 2, Value : positive
# Index : 3, Value : negative
# Index : 4, Value : positive
# Index : 5, Value : positive
# Index : 6, Value : positive
# Index : 7, Value : negative
# Index : 8, Value : negative
# Index : 9, Value : positive
# Index : 10, Value : negative
# Index : 11, Value : negative
# Index : 12, Value : negative
# Index : 13, Value : negative
# Index : 14, Value : positive
# Index : 15, Value : negative
# Index : 16, Value : positive
# Index : 17, Value : negative
# Index : 18, Value : positive
# Index : 19, Value : negative
# Index : 20, Value : positive
# Index : 21, Value : negative
# Index : 22, Value : positive
# Index : 23, Value : negative
# Index : 24, Value : negative
# Index : 25, Value : positive
# Index : 26, Value : positive
# Index : 27, Value : negative
# Index : 28, Value : negative
# Index : 29, Value : positive
# Index : 30, Value : positive
# Index : 31, Value : positive
# ...

# %%
X_train_tf
# Out:
# <40000x174922 sparse matrix of type '<class 'numpy.float64'>'
# 	with 3374356 stored elements in Compressed Sparse Row format>

# %%
naive_bayes_classifier = MultinomialNB() # create object naive_bayes_classifier
naive_bayes_classifier.fit(X_train_tf, train_y) # run method fit from the class MultinomialNB


# TODO for just Bayes Classifier
# Out:
# MultinomialNB()

# %%
# predict the new document from the testing dataset
X_test_tf = tf_vectorizer.transform(test_X) # Create a Vector TF from test data 
y_pred = naive_bayes_classifier.predict(X_test_tf)
 
# compute the performance measures
score1 = metrics.accuracy_score(test_y, y_pred)
print("accuracy:   %0.3f" % score1)

print(metrics.classification_report(test_y, y_pred,
                                            target_names=['Positive', 'Negative']))

print("confusion matrix:")
print(metrics.confusion_matrix(test_y, y_pred))

print('------------------------------')
# Out:
# accuracy:   0.913
#               precision    recall  f1-score   support
#
#     Positive       0.91      0.92      0.91      5022
#     Negative       0.92      0.90      0.91      4978
#
#     accuracy                           0.91     10000
#    macro avg       0.91      0.91      0.91     10000
# weighted avg       0.91      0.91      0.91     10000
#
# confusion matrix:
# [[4627  395]
#  [ 474 4504]]
# ------------------------------

# %%
from sklearn.neighbors import KNeighborsClassifier

neigh = KNeighborsClassifier(n_neighbors=3)
neigh.fit(X_train_tf, train_y)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
# predict the new document from the testing dataset
 
y_pred = neigh.predict(X_test_tf)
 
# compute the performance measures
score1 = metrics.accuracy_score(test_y, y_pred)
print("accuracy:   %0.3f" % score1)

print(metrics.classification_report(test_y, y_pred,
                                            target_names=['Positive', 'Negative']))

print("confusion matrix:")
print(metrics.confusion_matrix(test_y, y_pred))

print('------------------------------')
# Out:
# accuracy:   0.989
#               precision    recall  f1-score   support
#
#     Positive       0.99      1.00      0.99      9898
#     Negative       0.00      0.00      0.00       102
#
#     accuracy                           0.99     10000
#    macro avg       0.49      0.50      0.50     10000
# weighted avg       0.98      0.99      0.98     10000
#
# confusion matrix:
# [[9894    4]
#  [ 102    0]]
# ------------------------------
